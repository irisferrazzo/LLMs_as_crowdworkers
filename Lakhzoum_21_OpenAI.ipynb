# %% [markdown]
# # Beyond Correlation: Why Likert-Scale Calibration Challenges LLM-as-Participant Designs.

# %% [markdown]
# # Code structure: #
#
# In the **first block** of the code, some libraries (such as openai) are imported and the own API-key of OpenAI is defined.

# %%
import os
from openai import OpenAI

os.environ["OPENAI_API_KEY"] = "" # insert here OpenAI API key
# Out:
# This is a test, it works! How can I assist you further?

# %% [markdown]
# The **second block** of the code contains the prompt engineering functions that we will use later. You will find zero and few shot prompting as example functions. However, only the zero-shot function is applied in the next steps, since few-shot prompting performed poorely in first pilot studies.

# %%
import openai
from openai import OpenAI

# Funktion zur Durchführung von Null-Shot-Prompting
def zero_shot_prompting(task, prompt):
    """
    Führt Null-Shot-Prompting durch, indem ein Prompt an das Sprachmodell gesendet wird,
    ohne dass vorherige Beispiele gegeben werden.

    Args:
    task (str): Die Aufgabe, die durchgeführt werden soll.
    prompt (str): Der Text, der als Eingabe an das Sprachmodell gesendet wird.

    Returns:
    str: Die Antwort des Sprachmodells.
    """
    # Erstellen der Chat-Nachricht und Senden an das Sprachmodell
    response = client.chat.completions.create(
        model="o4-mini",
        messages=[
            {"role": "system", "content": "Tu es un(e) assistant(e)"}, # HIER ÄNDERN, WENN GEWÜNSCHT
            {"role": "user", "content": prompt} # Benutzernachricht mit dem eigentlichen Prompt
        ]
    )
    # Rückgabe des Inhalts der ersten Antwortnachricht des Modells
    return response.choices[0].message.content



# Funktion zur Durchführung von Few-Shot-Prompting
def few_shot_prompting(task, examples, prompt):
    """
    Führt Few-Shot-Prompting durch, indem einige Beispiele gegeben werden,
    bevor der eigentliche Prompt an das Sprachmodell gesendet wird.

    Args:
    task (str): Die Aufgabe, die durchgeführt werden soll.
    examples (list of dict): Eine Liste von Beispielen, wobei jedes Beispiel ein Wörterbuch mit 'input' und 'output' enthält.
    prompt (str): Der Text, der als Eingabe an das Sprachmodell gesendet wird.

    Returns:
    str: Die Antwort des Sprachmodells.
    """
    # Initialisieren der Nachrichtenliste mit einer Systemnachricht
    messages = [{"role": "system", "content": "Tu es un(e) assistant(e)"}] # HIER ÄNDERN, WENN GEWÜNSCHT

    # Hinzufügen der Beispiele zu den Nachrichten
    for example in examples:
        messages.append({"role": "user", "content": example['input']})
        messages.append({"role": "assistant", "content": example['output']})

    # Hinzufügen des eigentlichen Prompts zur Nachrichtenliste
    messages.append({"role": "user", "content": prompt})

    # Erstellen der Chat-Nachricht und Senden an das Sprachmodell
    response = client.chat.completions.create(
        model="o4-mini",
        messages=messages
    )
    # Rückgabe des Inhalts der ersten Antwortnachricht des Modells
    return response.choices[0].message.content

# %% [markdown]
# In the **third block** of the code you find code so that you can read in your uploaded data. This will be helpful in presenting the data to the LLM during prompting.

# %%
import pandas as pd
import time
import json
import gc
from psutil import virtual_memory
from datetime import datetime
import random

# Load data
daten = '630similarFrenchWordPair.csv'  # Adjust the filename as needed
df = pd.read_csv(daten)

# Extract specific columns and pack them into a dictionary
columns_to_extract = ['wordPairs', 'PairMeanConcreteness', 'clusters', 'MeanPairSimilarity']
selected_data = df[columns_to_extract].astype(str)
stimuli_dict = selected_data.to_dict(orient="index")

# Create list of items
all_items = [entry['wordPairs'] for entry in stimuli_dict.values()]
#random.shuffle(all_items)
print("The materials for the study are:")

n = len(all_items) // 6

part1 = all_items[0*n : 1*n]
print("list 1:", part1)
part2 = all_items[1*n : 2*n]
part3 = all_items[2*n : 3*n]
part4 = all_items[3*n : 4*n]
part5 = all_items[4*n : 5*n]
part6 = all_items[5*n : 6*n]
# Out:
# The materials for the study are:
# list 1: ['abdiquer-abandonner', 'abdomen-ventre', 'abeille-guêpe', 'abolir-annuler', 'absence-manque', 'abstrait-irréel', 'absurde-ridicule', 'acceptation-accord', 'activisme-militantisme', 'addition-somme', 'admirer-célébrer', 'adulte-enfant', 'aérien-vaporeux', 'aéroport-gare', 'affichage-présentation', 'agence-bureau', 'agile-adroit', 'agilité-habileté', 'agitation-troubles', 'agiter-secouer', 'agriculteur-chasseur', 'aigle-faucon', 'album-classeur', 'algèbre-maths', 'alias-pseudonyme', 'allégorie-métaphore', 'alphabet-chiffre', 'altruisme-bonté', 'ambassade-consulat', 'ambition-désir', 'amer-acide', 'amour-adoration', 'ampoule-bougie', 'analogie-exemple', 'anatomie-forme', 'ancre-grappin', 'animal-bête', 'anormal-étrange', 'anxiété-crainte', 'apathie-ennui', 'appartenir-dépendre', 'apprendre-savoir', 'après-futur', 'arbitraire-injuste', 'arbitre-juge', 'architecture-construction', 'argent-monnaie', 'arrivée-approche', 'arrogance-vanité', 'artisanat-métier', 'aspect-caractère', 'assigner-déléguer', 'assurance-sécurité', 'astronaute-aviateur', 'astronomie-géologie', 'atrocité-horreur', 'attitude-comportement', 'austérité-sévérité', 'auteur-écrivain', 'autre-soi', 'avaler-boire', 'aveu-confession', 'axiome-théorie', 'bagarre-combat', 'banalité-cliché', 'bataille-lutte', 'bateau-navire', 'bâtiment-immeuble', 'béatitude-joie', 'bébé-enfant', 'bénédiction-grâce', 'berceau-lit', 'bibliothèque-étagère', 'bien-bon', 'billet-bulletin', 'biologie-chimie', 'blague-plaisanterie', 'blessure-plaie', 'boire-manger', 'bois-métal', 'bonheur-joie', 'botte-soulier', 'bouclier-armure', 'bouée-balise', 'bourgeois-riche', 'brise-vent', 'budget-bourse', 'bulle-ballon', 'cage-boîte', 'camion-voiture', 'camp-colonie', 'candidat-concurrent', 'capitaine-chef', 'capitalisme-finance', 'cartable-sac', 'casque-chapeau', 'catastrophe-drame', 'caverne-abri', 'célébrité-gloire', 'céleri-tomate', 'céleste-spatial', 'célibataire-seul', 'cerceau-anneau', 'cercle-courbe']

# %% [markdown]
# In the **fourth block** we can apply the prompt engineering functions of block 2. We will formulate our prompts in this cell. In this block, we can test different prompting strategies. We prompt the model as many times as we have (or want to have) particpants tu simulate.

# %%
# Prompting mit allen Probanden und mit dem ganzen korpus

antworten_null_shot_all = {}
probanden_zahl= 62
items = part1
reaction_time_per_participant=list()

import time  # Import the time module

for iteration in range(probanden_zahl + 1):  # Repeat the process
    print(f"### LLM-informant {iteration} ###")

    antworten_null_shot = {}  # Dictionary for null-shot responses in this iteration

    # === Null-Shot ===
    # Record the start time
    start_time_pro_part = time.time()

    for i, text in enumerate(items):
        start_time = time.time()
        zero_shot_prompt = f"Nous allons vous présenter deux mots separées de un -. Votre tâche consiste à réfléchir au sens de ces mots et indiquer sur une échelle en 7 points à quel point vous considérez que ces deux mots sont similaires sémantiquement (qu’ils ont le même sens). Si vous considérez que les deux mots de la paire sont très similaires sémantiquement, vous pouvez choisir le point 7 (« tout à fait similaires »). Si vous considérez que les deux mots de la paire sont très différents sémantiquement, vous pouvez choisir le point 1 (« pas du tout similaires »). Vous pouvez utiliser tous les points de l’échelle. Par exemple, si la paire présentée est professeur – enseignant, vous pouvez choisir le point 6. Si la paire présentée est lune – route, vous pouvez choisir le point 1. N’hésitez pas à utiliser toute la gamme des chiffres comprise entre 1 et 7 mais ne vous préoccupez pas du nombre de fois que vous avez utilisé un chiffre en particulier tant qu’il fait référence à votre véritable jugement. Il n'y a pas de bonne ou de mauvaise réponse. Veuillez donc répondre le plus spontanément possible. Ne donnez pas d'éxplications. Les mots sont: '{text}'"
        zero_shot = zero_shot_prompting("jugement", zero_shot_prompt)

        # Record the end time and calculate the elapsed time for this sentence
        elapsed_time = time.time() - start_time

        # Save the response in the dictionary with the index as the key
        antworten_null_shot[i] = {
            "Prompt": zero_shot_prompt,
            "Antwort": zero_shot,
            "Zeit": elapsed_time
        }

        #print(f"Input: {text}")
        print(f"Output: {zero_shot}")
        print(i,f"Time taken: {elapsed_time:.2f} seconds")
        print()

    # Calculate elapsed time for the iteration
    elapsed_time_pro_part = time.time() - start_time_pro_part

    # Save the null-shot results of this iteration in the parent dictionary
    antworten_null_shot_all[iteration] = antworten_null_shot
    reaction_time_per_participant.append(elapsed_time_pro_part)
    print(f"Elapsed time for iteration {iteration}: {elapsed_time_pro_part:.2f} seconds")
    print()

print(antworten_null_shot_all)
print("Mean reaction time per participant:", sum(reaction_time_per_participant)/len(reaction_time_per_participant))
# Out:
# ### LLM-informant 51 ###
# Output: 7
# 0 Time taken: 2.35 seconds
#
# Output: 3
# 1 Time taken: 2.50 seconds
#
# Output: 5
# 2 Time taken: 2.35 seconds
#
# Output: 4
# 3 Time taken: 2.14 seconds
#
# Output: 3
# 4 Time taken: 3.59 seconds
#
# Output: 5
# 5 Time taken: 3.70 seconds
#
# Output: 4
# 6 Time taken: 2.71 seconds
#
# Output: 4
# 7 Time taken: 2.87 seconds
#
# Output: 5
# 8 Time taken: 2.96 seconds
#
# Output: 6
# 9 Time taken: 2.65 seconds
#
# Output: 6
# 10 Time taken: 1.50 seconds
#
# Output: 7
# 11 Time taken: 1.52 seconds
#
# Output: 5
# 12 Time taken: 3.20 seconds
#
# Output: 4
# 13 Time taken: 5.78 seconds
#
# Output: 3
# 14 Time taken: 2.40 seconds
#
# Output: 7
# 15 Time taken: 2.08 seconds
#
# Output: 4
# 16 Time taken: 2.78 seconds
#
# Output: 5
# 17 Time taken: 3.60 seconds
#
# Output: 4
# 18 Time taken: 3.48 seconds
#
# Output: 2
# 19 Time taken: 3.12 seconds
#
# Output: 7
# 20 Time taken: 2.43 seconds
#
# Output: 3
# 21 Time taken: 2.83 seconds
#
# Output: 5
# 22 Time taken: 3.09 seconds
#
# Output: 5
# 23 Time taken: 2.27 seconds
#
# Output: 4
# 24 Time taken: 2.97 seconds
#
# Output: 5
# 25 Time taken: 2.36 seconds
#
# Output: 7
# 26 Time taken: 1.93 seconds
#
# Output: 7
# 27 Time taken: 1.63 seconds
#
# Output: 5
# 28 Time taken: 2.01 seconds
#
# Output: 2
# 29 Time taken: 2.46 seconds
#
# Output: 6
# 30 Time taken: 1.96 seconds
#
# Output: 4
# 31 Time taken: 3.31 seconds
#
# Output: 6
# 32 Time taken: 3.73 seconds
#
# Output: 6
# 33 Time taken: 2.27 seconds
#
# Output: 6
# 34 Time taken: 2.33 seconds
#
# Output: 5
# 35 Time taken: 1.76 seconds
#
# Output: 6
# 36 Time taken: 2.45 seconds
#
# Output: 6
# 37 Time taken: 2.61 seconds
#
# Output: 5
# 38 Time taken: 3.24 seconds
#
# Output: 4
# 39 Time taken: 2.26 seconds
#
# Output: 6
# 40 Time taken: 1.98 seconds
#
# Output: 4
# 41 Time taken: 2.49 seconds
#
# Output: 4
# 42 Time taken: 4.26 seconds
#
# Output: 5
# 43 Time taken: 2.17 seconds
#
# Output: 6
# 44 Time taken: 2.42 seconds
#
# Output: 4
# 45 Time taken: 1.69 seconds
#
# Output: 6
# 46 Time taken: 2.77 seconds
#
# Output: 5
# 47 Time taken: 2.31 seconds
#
# Output: 6
# 48 Time taken: 2.40 seconds
#
# Output: 7
# 49 Time taken: 2.18 seconds
#
# Output: 6
# 50 Time taken: 2.05 seconds
#
# Output: 7
# 51 Time taken: 1.89 seconds
#
# Output: 7
# 52 Time taken: 2.34 seconds
#
# Output: 7
# 53 Time taken: 3.10 seconds
#
# Output: 5
# 54 Time taken: 2.66 seconds
#
# Output: 6
# 55 Time taken: 2.50 seconds
#
# Output: 6
# 56 Time taken: 3.00 seconds
#
# Output: 4
# 57 Time taken: 3.05 seconds
#
# Output: 6
# 58 Time taken: 2.11 seconds
#
# Output: 3
# 59 Time taken: 2.23 seconds
#
# Output: 3
# 60 Time taken: 2.34 seconds
#
# Output: 6
# 61 Time taken: 4.93 seconds
#
# Output: 5
# 62 Time taken: 2.38 seconds
#
# Output: 4
# 63 Time taken: 1.77 seconds
#
# Output: 6
# 64 Time taken: 2.31 seconds
#
# Output: 4
# 65 Time taken: 2.27 seconds
#
# Output: 4
# 66 Time taken: 2.83 seconds
#
# Output: 2
# 67 Time taken: 1.65 seconds
#
# Output: 6
# 68 Time taken: 2.02 seconds
#
# Output: 6
# 69 Time taken: 3.46 seconds
#
# Output: 3
# 70 Time taken: 3.67 seconds
#
# Output: 4
# 71 Time taken: 3.06 seconds
#
# Output: 4
# 72 Time taken: 3.95 seconds
#
# Output: 4
# 73 Time taken: 2.83 seconds
#
# Output: 6
# 74 Time taken: 3.47 seconds
#
# Output: 6
# 75 Time taken: 2.30 seconds
#
# Output: 5
# 76 Time taken: 2.68 seconds
#
# Output: 4
# 77 Time taken: 2.33 seconds
#
# Output: 6
# 78 Time taken: 3.12 seconds
#
# Output: 4
# 79 Time taken: 2.01 seconds
#
# Output: 6
# 80 Time taken: 2.32 seconds
#
# Output: 7
# 81 Time taken: 1.97 seconds
#
# Output: 5
# 82 Time taken: 2.92 seconds
#
# Output: 5
# 83 Time taken: 4.36 seconds
#
# Output: 4
# 84 Time taken: 2.10 seconds
#
# Output: 5
# 85 Time taken: 2.78 seconds
#
# Output: 5
# 86 Time taken: 2.37 seconds
#
# Output: 4
# 87 Time taken: 3.91 seconds
#
# Output: 4
# 88 Time taken: 2.03 seconds
#
# Output: 3
# 89 Time taken: 2.86 seconds
#
# Output: 5
# 90 Time taken: 3.53 seconds
#
# Output: 6
# 91 Time taken: 2.40 seconds
#
# Output: 5
# 92 Time taken: 3.17 seconds
#
# Output: 4
# 93 Time taken: 2.03 seconds
#
# Output: 5
# 94 Time taken: 3.86 seconds
#
# Output: 5
# 95 Time taken: 1.88 seconds
#
# Output: 5
# 96 Time taken: 3.67 seconds
#
# Output: 7
# 97 Time taken: 2.72 seconds
#
# Output: 6
# 98 Time taken: 2.73 seconds
#
# Output: 6
# 99 Time taken: 2.41 seconds
#
# Output: 2
# 100 Time taken: 2.63 seconds
#
# Output: 7
# 101 Time taken: 1.43 seconds
#
# Output: 4
# 102 Time taken: 2.14 seconds
#
# Output: 6
# 103 Time taken: 2.37 seconds
#
# Elapsed time for iteration 51: 276.70 seconds
#
# ### LLM-informant 52 ###
# Output: 6
# 0 Time taken: 1.97 seconds
#
# Output: 4
# 1 Time taken: 1.90 seconds
#
# Output: 5
# 2 Time taken: 1.92 seconds
#
# Output: 4
# 3 Time taken: 3.21 seconds
#
# Output: 3
# 4 Time taken: 2.58 seconds
#
# Output: 4
# 5 Time taken: 2.42 seconds
#
# Output: 5
# 6 Time taken: 2.30 seconds
#
# Output: 4
# 7 Time taken: 3.97 seconds
#
# Output: 6
# 8 Time taken: 3.01 seconds
#
# Output: 5
# 9 Time taken: 2.24 seconds
#
# Output: 6
# 10 Time taken: 3.84 seconds
#
# Output: 7
# 11 Time taken: 1.53 seconds
#
# Output: 6
# 12 Time taken: 2.80 seconds
#
# Output: 5
# 13 Time taken: 2.75 seconds
#
# Output: 5
# 14 Time taken: 3.90 seconds
#
# Output: 7
# 15 Time taken: 2.97 seconds
#
# Output: 5
# 16 Time taken: 2.79 seconds
#
# Output: 5
# 17 Time taken: 2.19 seconds
#
# Output: 4
# 18 Time taken: 2.23 seconds
#
# Output: 2
# 19 Time taken: 2.82 seconds
#
# Output: 7
# 20 Time taken: 3.29 seconds
#
# Output: 4
# 21 Time taken: 4.92 seconds
#
# Output: 5
# 22 Time taken: 3.27 seconds
#
# Output: 6
# 23 Time taken: 2.82 seconds
#
# Output: 4
# 24 Time taken: 2.54 seconds
#
# Output: 5
# 25 Time taken: 2.90 seconds
#
# Output: 7
# 26 Time taken: 1.80 seconds
#
# Output: 7
# 27 Time taken: 2.14 seconds
#
# Output: 6
# 28 Time taken: 2.74 seconds
#
# Output: 4
# 29 Time taken: 2.76 seconds
#
# Output: 6
# 30 Time taken: 3.03 seconds
#
# Output: 3
# 31 Time taken: 3.28 seconds
#
# Output: 6
# 32 Time taken: 3.01 seconds
#
# Output: 5
# 33 Time taken: 3.14 seconds
#
# Output: 6
# 34 Time taken: 2.84 seconds
#
# Output: 4
# 35 Time taken: 2.67 seconds
#
# Output: 5
# 36 Time taken: 1.82 seconds
#
# Output: 7
# 37 Time taken: 3.42 seconds
#
# Output: 5
# 38 Time taken: 3.05 seconds
#
# Output: 4
# 39 Time taken: 4.16 seconds
#
# Output: 6
# 40 Time taken: 1.59 seconds
#
# Output: 5
# 41 Time taken: 2.45 seconds
#
# Output: 4
# 42 Time taken: 3.49 seconds
#
# Output: 5
# 43 Time taken: 2.98 seconds
#
# Output: 6
# 44 Time taken: 2.34 seconds
#
# Output: 3
# 45 Time taken: 4.33 seconds
#
# Output: 6
# 46 Time taken: 2.96 seconds
#
# Output: 4
# 47 Time taken: 2.67 seconds
#
# Output: 6
# 48 Time taken: 2.10 seconds
#
# Output: 6
# 49 Time taken: 2.27 seconds
#
# Output: 6
# 50 Time taken: 1.91 seconds
#
# Output: 7
# 51 Time taken: 2.07 seconds
#
# Output: 7
# 52 Time taken: 2.92 seconds
#
# Output: 7
# 53 Time taken: 2.29 seconds
#
# Output: 4
# 54 Time taken: 2.26 seconds
#
# Output: 6
# 55 Time taken: 4.70 seconds
#
# Output: 6
# 56 Time taken: 2.58 seconds
#
# Output: 3
# 57 Time taken: 3.05 seconds
#
# Output: 6
# 58 Time taken: 2.42 seconds
#
# Output: 2
# 59 Time taken: 2.70 seconds
#
# Output: 4
# 60 Time taken: 2.65 seconds
#
# Output: 6
# 61 Time taken: 3.45 seconds
#
# Output: 6
# 62 Time taken: 3.24 seconds
#
# Output: 4
# 63 Time taken: 2.60 seconds
#
# Output: 6
# 64 Time taken: 4.71 seconds
#
# Output: 2
# 65 Time taken: 1.49 seconds
#
# Output: 3
# 66 Time taken: 1.96 seconds
#
# Output: 2
# 67 Time taken: 7.90 seconds
#
# Output: 6
# 68 Time taken: 2.31 seconds
#
# Output: 6
# 69 Time taken: 2.93 seconds
#
# Output: 2
# 70 Time taken: 2.53 seconds
#
# Output: 2
# 71 Time taken: 3.22 seconds
#
# Output: 5
# 72 Time taken: 3.37 seconds
#
# Output: 5
# 73 Time taken: 2.12 seconds
#
# Output: 6
# 74 Time taken: 2.23 seconds
#
# Output: 6
# 75 Time taken: 2.11 seconds
#
# Output: 4
# 76 Time taken: 2.69 seconds
#
# Output: 5
# 77 Time taken: 2.90 seconds
#
# Output: 6
# 78 Time taken: 1.66 seconds
#
# Output: 4
# 79 Time taken: 5.15 seconds
#
# Output: 6
# 80 Time taken: 1.88 seconds
#
# Output: 6
# 81 Time taken: 2.61 seconds
#
# Output: 6
# 82 Time taken: 2.68 seconds
#
# Output: 5
# 83 Time taken: 3.43 seconds
#
# Output: 5
# 84 Time taken: 3.13 seconds
#
# Output: 5
# 85 Time taken: 3.02 seconds
#
# Output: 5
# 86 Time taken: 2.37 seconds
#
# Output: 4
# 87 Time taken: 2.98 seconds
#
# Output: 4
# 88 Time taken: 2.35 seconds
#
# Output: 4
# 89 Time taken: 2.53 seconds
#
# Output: 6
# 90 Time taken: 2.82 seconds
#
# Output: 7
# 91 Time taken: 4.73 seconds
#
# Output: 5
# 92 Time taken: 4.58 seconds
#
# Output: 3
# 93 Time taken: 3.24 seconds
#
# Output: 5
# 94 Time taken: 2.63 seconds
#
# Output: 5
# 95 Time taken: 3.50 seconds
#
# Output: 5
# 96 Time taken: 4.04 seconds
#
# Output: 7
# 97 Time taken: 2.53 seconds
#
# Output: 6
# 98 Time taken: 2.64 seconds
#
# Output: 6
# 99 Time taken: 2.07 seconds
#
# Output: 2
# 100 Time taken: 2.89 seconds
#
# Output: 6
# 101 Time taken: 3.86 seconds
#
# Output: 4
# 102 Time taken: 2.56 seconds
#
# Output: 6
# 103 Time taken: 1.90 seconds
#
# Elapsed time for iteration 52: 299.25 seconds
#
# ### LLM-informant 53 ###
# Output: 7
# 0 Time taken: 2.39 seconds
#
# Output: 2
# 1 Time taken: 2.50 seconds
#
# Output: 5
# 2 Time taken: 2.11 seconds
#
# Output: 5
# 3 Time taken: 2.97 seconds
#
# Output: 4
# 4 Time taken: 2.32 seconds
#
# Output: 3
# 5 Time taken: 3.16 seconds
#
# Output: 6
# 6 Time taken: 2.13 seconds
#
# Output: 4
# 7 Time taken: 2.53 seconds
#
# Output: 5
# 8 Time taken: 2.15 seconds
#
# Output: 6
# 9 Time taken: 2.39 seconds
#
# Output: 6
# 10 Time taken: 1.89 seconds
#
# Output: 7
# 11 Time taken: 1.88 seconds
#
# Output: 5
# 12 Time taken: 3.13 seconds
#
# Output: 5
# 13 Time taken: 2.65 seconds
#
# Output: 4
# 14 Time taken: 1.95 seconds
#
# Output: 7
# 15 Time taken: 2.03 seconds
#
# Output: 5
# 16 Time taken: 3.17 seconds
#
# Output: 5
# 17 Time taken: 3.05 seconds
#
# Output: 4
# 18 Time taken: 2.66 seconds
#
# Output: 2
# 19 Time taken: 3.89 seconds
#
# Output: 7
# 20 Time taken: 3.12 seconds
#
# Output: 4
# 21 Time taken: 2.52 seconds
#
# Output: 5
# 22 Time taken: 2.21 seconds
#
# Output: 6
# 23 Time taken: 2.46 seconds
#
# Output: 4
# 24 Time taken: 3.03 seconds
#
# Output: 5
# 25 Time taken: 2.75 seconds
#
# Output: 7
# 26 Time taken: 1.67 seconds
#
# Output: 7
# 27 Time taken: 1.96 seconds
#
# Output: 5
# 28 Time taken: 3.55 seconds
#
# Output: 3
# 29 Time taken: 2.76 seconds
#
# Output: 6
# 30 Time taken: 2.87 seconds
#
# Output: 3
# 31 Time taken: 2.71 seconds
#
# Output: 5
# 32 Time taken: 5.91 seconds
#
# Output: 6
# 33 Time taken: 2.46 seconds
#
# Output: 6
# 34 Time taken: 1.46 seconds
#
# Output: 5
# 35 Time taken: 2.15 seconds
#
# Output: 5
# 36 Time taken: 2.24 seconds
#
# Output: 6
# 37 Time taken: 2.32 seconds
#
# Output: 5
# 38 Time taken: 2.32 seconds
#
# Output: 4
# 39 Time taken: 4.77 seconds
#
# Output: 6
# 40 Time taken: 3.88 seconds
#
# Output: 4
# 41 Time taken: 1.90 seconds
#
# Output: 5
# 42 Time taken: 3.59 seconds
#
# Output: 5
# 43 Time taken: 2.45 seconds
#
# Output: 6
# 44 Time taken: 1.54 seconds
#
# Output: 2
# 45 Time taken: 2.09 seconds
#
# Output: 6
# 46 Time taken: 2.47 seconds
#
# Output: 5
# 47 Time taken: 3.77 seconds
#
# Output: 6
# 48 Time taken: 2.39 seconds
#
# Output: 7
# 49 Time taken: 2.63 seconds
#
# Output: 6
# 50 Time taken: 3.96 seconds
#
# Output: 6
# 51 Time taken: 2.93 seconds
#
# Output: 7
# 52 Time taken: 2.97 seconds
#
# Output: 7
# 53 Time taken: 1.52 seconds
#
# Output: 5
# 54 Time taken: 3.12 seconds
#
# Output: 6
# 55 Time taken: 2.43 seconds
#
# Output: 6
# 56 Time taken: 3.26 seconds
#
# Output: 4
# 57 Time taken: 2.17 seconds
#
# Output: 6
# 58 Time taken: 5.00 seconds
#
# Output: 2
# 59 Time taken: 2.38 seconds
#
# Output: 4
# 60 Time taken: 2.08 seconds
#
# Output: 6
# 61 Time taken: 1.61 seconds
#
# Output: 6
# 62 Time taken: 2.34 seconds
#
# Output: 2
# 63 Time taken: 2.23 seconds
#
# Output: 6
# 64 Time taken: 3.42 seconds
#
# Output: 2
# 65 Time taken: 2.51 seconds
#
# Output: 4
# 66 Time taken: 2.23 seconds
#
# Output: 3
# 67 Time taken: 2.17 seconds
#
# Output: 6
# 68 Time taken: 3.17 seconds
#
# Output: 6
# 69 Time taken: 2.54 seconds
#
# Output: 4
# 70 Time taken: 2.98 seconds
#
# Output: 4
# 71 Time taken: 3.46 seconds
#
# Output: 5
# 72 Time taken: 2.28 seconds
#
# Output: 5
# 73 Time taken: 4.42 seconds
#
# Output: 5
# 74 Time taken: 2.49 seconds
#
# Output: 6
# 75 Time taken: 2.60 seconds
#
# Output: 4
# 76 Time taken: 2.60 seconds
#
# Output: 4
# 77 Time taken: 2.56 seconds
#
# Output: 6
# 78 Time taken: 2.32 seconds
#
# Output: 2
# 79 Time taken: 3.20 seconds
#
# Output: 6
# 80 Time taken: 2.35 seconds
#
# Output: 6
# 81 Time taken: 2.79 seconds
#
# Output: 6
# 82 Time taken: 5.10 seconds
#
# Output: 5
# 83 Time taken: 2.52 seconds
#
# Output: 5
# 84 Time taken: 2.63 seconds
#
# Output: 5
# 85 Time taken: 2.94 seconds
#
# Output: 4
# 86 Time taken: 2.73 seconds
#
# Output: 4
# 87 Time taken: 2.49 seconds
#
# Output: 4
# 88 Time taken: 2.57 seconds
#
# Output: 3
# 89 Time taken: 3.23 seconds
#
# Output: 5
# 90 Time taken: 3.28 seconds
#
# Output: 7
# 91 Time taken: 1.94 seconds
#
# Output: 5
# 92 Time taken: 3.15 seconds
#
# Output: 3
# 93 Time taken: 2.41 seconds
#
# Output: 4
# 94 Time taken: 3.13 seconds
#
# Output: 5
# 95 Time taken: 2.26 seconds
#
# Output: 6
# 96 Time taken: 4.55 seconds
#
# Output: 7
# 97 Time taken: 2.31 seconds
#
# Output: 6
# 98 Time taken: 2.62 seconds
#
# Output: 6
# 99 Time taken: 2.81 seconds
#
# Output: 2
# 100 Time taken: 2.51 seconds
#
# Output: 6
# 101 Time taken: 2.65 seconds
#
# Output: 5
# 102 Time taken: 2.58 seconds
#
# Output: 6
# 103 Time taken: 2.04 seconds
#
# Elapsed time for iteration 53: 283.43 seconds
#
# ### LLM-informant 54 ###
# Output: 6
# 0 Time taken: 3.12 seconds
#
# Output: 3
# 1 Time taken: 1.64 seconds
#
# Output: 5
# 2 Time taken: 3.65 seconds
#
# Output: 4
# 3 Time taken: 2.39 seconds
#
# Output: 4
# 4 Time taken: 2.85 seconds
#
# Output: 4
# 5 Time taken: 2.27 seconds
#
# Output: 6
# 6 Time taken: 2.44 seconds
#
# Output: 4
# 7 Time taken: 2.06 seconds
#
# Output: 5
# 8 Time taken: 2.12 seconds
#
# Output: 5
# 9 Time taken: 2.31 seconds
#
# Output: 6
# 10 Time taken: 2.16 seconds
#
# Output: 7
# 11 Time taken: 1.82 seconds
#
# Output: 6
# 12 Time taken: 3.02 seconds
#
# Output: 5
# 13 Time taken: 2.99 seconds
#
# Output: 4
# 14 Time taken: 2.82 seconds
#
# Output: 7
# 15 Time taken: 2.11 seconds
#
# Output: 5
# 16 Time taken: 3.80 seconds
#
# Output: 5
# 17 Time taken: 2.33 seconds
#
# Output: 4
# 18 Time taken: 2.14 seconds
#
# Output: 2
# 19 Time taken: 3.14 seconds
#
# Output: 7
# 20 Time taken: 1.74 seconds
#
# Output: 3
# 21 Time taken: 3.35 seconds
#
# Output: 5
# 22 Time taken: 2.24 seconds
#
# Output: 6
# 23 Time taken: 1.68 seconds
#
# Output: 4
# 24 Time taken: 2.45 seconds
#
# Output: 4
# 25 Time taken: 2.96 seconds
#
# Output: 6
# 26 Time taken: 2.92 seconds
#
# Output: 7
# 27 Time taken: 2.04 seconds
#
# Output: 4
# 28 Time taken: 2.79 seconds
#
# Output: 5
# 29 Time taken: 3.13 seconds
#
# Output: 6
# 30 Time taken: 1.57 seconds
#
# Output: 2
# 31 Time taken: 1.78 seconds
#
# Output: 6
# 32 Time taken: 2.27 seconds
#
# Output: 6
# 33 Time taken: 2.58 seconds
#
# Output: 6
# 34 Time taken: 2.01 seconds
#
# Output: 5
# 35 Time taken: 1.44 seconds
#
# Output: 6
# 36 Time taken: 1.32 seconds
#
# Output: 6
# 37 Time taken: 3.91 seconds
#
# Output: 5
# 38 Time taken: 2.34 seconds
#
# Output: 5
# 39 Time taken: 2.40 seconds
#
# Output: 6
# 40 Time taken: 2.35 seconds
#
# Output: 4
# 41 Time taken: 3.12 seconds
#
# Output: 4
# 42 Time taken: 2.09 seconds
#
# Output: 6
# 43 Time taken: 2.89 seconds
#
# Output: 6
# 44 Time taken: 2.49 seconds
#
# Output: 3
# 45 Time taken: 2.62 seconds
#
# Output: 6
# 46 Time taken: 1.77 seconds
#
# Output: 4
# 47 Time taken: 3.18 seconds
#
# Output: 6
# 48 Time taken: 2.32 seconds
#
# Output: 6
# 49 Time taken: 2.58 seconds
#
# Output: 7
# 50 Time taken: 3.78 seconds
#
# Output: 7
# 51 Time taken: 2.79 seconds
#
# Output: 7
# 52 Time taken: 2.61 seconds
#
# Output: 7
# 53 Time taken: 2.10 seconds
#
# Output: 4
# 54 Time taken: 2.11 seconds
#
# Output: 6
# 55 Time taken: 3.92 seconds
#
# Output: 6
# 56 Time taken: 3.93 seconds
#
# Output: 3
# 57 Time taken: 2.52 seconds
#
# Output: 6
# 58 Time taken: 3.21 seconds
#
# Output: 3
# 59 Time taken: 2.26 seconds
#
# Output: 4
# 60 Time taken: 1.72 seconds
#
# Output: 5
# 61 Time taken: 2.24 seconds
#
# Output: 5
# 62 Time taken: 1.97 seconds
#
# Output: 4
# 63 Time taken: 2.66 seconds
#
# Output: 6
# 64 Time taken: 5.17 seconds
#
# Output: 3
# 65 Time taken: 2.58 seconds
#
# Output: 4
# 66 Time taken: 2.16 seconds
#
# Output: 2
# 67 Time taken: 1.92 seconds
#
# Output: 6
# 68 Time taken: 3.11 seconds
#
# Output: 6
# 69 Time taken: 1.52 seconds
#
# Output: 2
# 70 Time taken: 3.40 seconds
#
# Output: 4
# 71 Time taken: 3.30 seconds
#
# Output: 5
# 72 Time taken: 2.24 seconds
#
# Output: 4
# 73 Time taken: 2.77 seconds
#
# Output: 5
# 74 Time taken: 3.27 seconds
#
# Output: 6
# 75 Time taken: 2.67 seconds
#
# Output: 2
# 76 Time taken: 3.97 seconds
#
# Output: 4
# 77 Time taken: 2.00 seconds
#
# Output: 7
# 78 Time taken: 2.55 seconds
#
# Output: 3
# 79 Time taken: 1.47 seconds
#
# Output: 5
# 80 Time taken: 3.19 seconds
#
# Output: 6
# 81 Time taken: 2.82 seconds
#
# Output: 7
# 82 Time taken: 2.75 seconds
#
# Output: 5
# 83 Time taken: 2.96 seconds
#
# Output: 4
# 84 Time taken: 2.57 seconds
#
# Output: 5
# 85 Time taken: 2.10 seconds
#
# Output: 5
# 86 Time taken: 2.61 seconds
#
# Output: 5
# 87 Time taken: 2.53 seconds
#
# Output: 4
# 88 Time taken: 1.90 seconds
#
# Output: 3
# 89 Time taken: 1.88 seconds
#
# Output: 4
# 90 Time taken: 2.75 seconds
#
# Output: 7
# 91 Time taken: 2.11 seconds
#
# Output: 5
# 92 Time taken: 2.10 seconds
#
# Output: 4
# 93 Time taken: 4.80 seconds
#
# Output: 4
# 94 Time taken: 4.50 seconds
#
# Output: 5
# 95 Time taken: 1.68 seconds
#
# Output: 6
# 96 Time taken: 3.60 seconds
#
# Output: 7
# 97 Time taken: 2.02 seconds
#
# Output: 6
# 98 Time taken: 4.20 seconds
#
# Output: 6
# 99 Time taken: 1.74 seconds
#
# Output: 1
# 100 Time taken: 3.59 seconds
#
# Output: 7
# 101 Time taken: 3.91 seconds
#
# Output: 2
# 102 Time taken: 1.95 seconds
#
# Output: 6
# 103 Time taken: 1.81 seconds
#
# Elapsed time for iteration 54: 271.52 seconds
#
# ### LLM-informant 55 ###
# Output: 6
# 0 Time taken: 4.01 seconds
#
# Output: 3
# 1 Time taken: 3.41 seconds
#
# Output: 5
# 2 Time taken: 2.49 seconds
#
# Output: 4
# 3 Time taken: 2.17 seconds
#
# Output: 4
# 4 Time taken: 4.96 seconds
#
# Output: 3
# 5 Time taken: 3.10 seconds
#
# Output: 5
# 6 Time taken: 2.75 seconds
#
# Output: 3
# 7 Time taken: 2.88 seconds
#
# Output: 5
# 8 Time taken: 6.40 seconds
#
# Output: 6
# 9 Time taken: 2.47 seconds
#
# Output: 7
# 10 Time taken: 2.95 seconds
#
# Output: 7
# 11 Time taken: 1.35 seconds
#
# Output: 5
# 12 Time taken: 3.34 seconds
#
# Output: 5
# 13 Time taken: 3.55 seconds
#
# Output: 4
# 14 Time taken: 3.15 seconds
#
# Output: 7
# 15 Time taken: 2.22 seconds
#
# Output: 4
# 16 Time taken: 2.05 seconds
#
# Output: 5
# 17 Time taken: 2.64 seconds
#
# Output: 4
# 18 Time taken: 2.38 seconds
#
# Output: 3
# 19 Time taken: 2.74 seconds
#
# Output: 6
# 20 Time taken: 2.15 seconds
#
# Output: 3
# 21 Time taken: 2.14 seconds
#
# Output: 6
# 22 Time taken: 3.25 seconds
#
# Output: 6
# 23 Time taken: 2.07 seconds
#
# Output: 4
# 24 Time taken: 6.06 seconds
#
# Output: 5
# 25 Time taken: 2.60 seconds
#
# Output: 7
# 26 Time taken: 2.97 seconds
#
# Output: 7
# 27 Time taken: 2.60 seconds
#
# Output: 4
# 28 Time taken: 2.82 seconds
#
# Output: 5
# 29 Time taken: 4.19 seconds
#
# Output: 6
# 30 Time taken: 3.22 seconds
#
# Output: 2
# 31 Time taken: 2.26 seconds
#
# Output: 6
# 32 Time taken: 2.72 seconds
#
# Output: 5
# 33 Time taken: 2.86 seconds
#
# Output: 6
# 34 Time taken: 2.44 seconds
#
# Output: 5
# 35 Time taken: 3.29 seconds
#
# Output: 5
# 36 Time taken: 2.50 seconds
#
# Output: 6
# 37 Time taken: 3.28 seconds
#
# Output: 5
# 38 Time taken: 1.88 seconds
#
# Output: 5
# 39 Time taken: 2.00 seconds
#
# Output: 6
# 40 Time taken: 3.53 seconds
#
# Output: 4
# 41 Time taken: 2.89 seconds
#
# Output: 4
# 42 Time taken: 3.12 seconds
#
# Output: 5
# 43 Time taken: 1.99 seconds
#
# Output: 7
# 44 Time taken: 2.43 seconds
#
# Output: 4
# 45 Time taken: 3.45 seconds
#
# Output: 6
# 46 Time taken: 3.31 seconds
#
# Output: 4
# 47 Time taken: 2.03 seconds
#
# Output: 6
# 48 Time taken: 1.71 seconds
#
# Output: 6
# 49 Time taken: 2.71 seconds
#
# Output: 6
# 50 Time taken: 2.33 seconds
#
# Output: 6
# 51 Time taken: 2.36 seconds
#
# Output: 7
# 52 Time taken: 2.29 seconds
#
# Output: 7
# 53 Time taken: 1.71 seconds
#
# Output: 4
# 54 Time taken: 2.35 seconds
#
# Output: 6
# 55 Time taken: 2.05 seconds
#
# Output: 7
# 56 Time taken: 2.15 seconds
#
# Output: 4
# 57 Time taken: 2.45 seconds
#
# Output: 6
# 58 Time taken: 1.72 seconds
#
# Output: 2
# 59 Time taken: 2.30 seconds
#
# Output: 5
# 60 Time taken: 2.70 seconds
#
# Output: 6
# 61 Time taken: 2.05 seconds
#
# Output: 6
# 62 Time taken: 2.82 seconds
#
# Output: 4
# 63 Time taken: 2.51 seconds
#
# Output: 6
# 64 Time taken: 5.58 seconds
#
# Output: 2
# 65 Time taken: 2.58 seconds
#
# Output: 4
# 66 Time taken: 1.78 seconds
#
# Output: 2
# 67 Time taken: 1.87 seconds
#
# Output: 6
# 68 Time taken: 2.61 seconds
#
# Output: 6
# 69 Time taken: 2.70 seconds
#
# Output: 3
# 70 Time taken: 2.38 seconds
#
# Output: 4
# 71 Time taken: 2.22 seconds
#
# Output: 5
# 72 Time taken: 2.35 seconds
#
# Output: 5
# 73 Time taken: 2.13 seconds
#
# Output: 4
# 74 Time taken: 1.54 seconds
#
# Output: 6
# 75 Time taken: 3.05 seconds
#
# Output: 5
# 76 Time taken: 3.26 seconds
#
# Output: 5
# 77 Time taken: 1.87 seconds
#
# Output: 6
# 78 Time taken: 2.26 seconds
#
# Output: 3
# 79 Time taken: 2.76 seconds
#
# Output: 6
# 80 Time taken: 1.84 seconds
#
# Output: 6
# 81 Time taken: 1.63 seconds
#
# Output: 6
# 82 Time taken: 2.45 seconds
#
# Output: 6
# 83 Time taken: 4.25 seconds
#
# Output: 5
# 84 Time taken: 5.17 seconds
#
# Output: 5
# 85 Time taken: 1.74 seconds
#
# Output: 4
# 86 Time taken: 2.90 seconds
#
# Output: 4
# 87 Time taken: 5.32 seconds
#
# Output: 4
# 88 Time taken: 3.47 seconds
#
# Output: 3
# 89 Time taken: 2.43 seconds
#
# Output: 4
# 90 Time taken: 2.53 seconds
#
# Output: 7
# 91 Time taken: 1.88 seconds
#
# Output: 5
# 92 Time taken: 7.82 seconds
#
# Output: 4
# 93 Time taken: 1.62 seconds
#
# Output: 4
# 94 Time taken: 2.86 seconds
#
# Output: 5
# 95 Time taken: 1.35 seconds
#
# Output: 6
# 96 Time taken: 2.49 seconds
#
# Output: 7
# 97 Time taken: 1.32 seconds
#
# Output: 6
# 98 Time taken: 2.28 seconds
#
# Output: 6
# 99 Time taken: 2.50 seconds
#
# Output: 2
# 100 Time taken: 2.61 seconds
#
# Output: 7
# 101 Time taken: 1.57 seconds
#
# Output: 4
# 102 Time taken: 2.46 seconds
#
# Output: 6
# 103 Time taken: 1.65 seconds
#
# Elapsed time for iteration 55: 284.37 seconds
#
# ### LLM-informant 56 ###
# Output: 6
# 0 Time taken: 1.80 seconds
#
# Output: 3
# 1 Time taken: 3.22 seconds
#
# Output: 6
# 2 Time taken: 2.06 seconds
#
# Output: 4
# 3 Time taken: 3.39 seconds
#
# Output: 3
# 4 Time taken: 2.05 seconds
#
# Output: 5
# 5 Time taken: 3.12 seconds
#
# Output: 5
# 6 Time taken: 2.26 seconds
#
# Output: 4
# 7 Time taken: 1.73 seconds
#
# Output: 5
# 8 Time taken: 3.02 seconds
#
# Output: 6
# 9 Time taken: 3.83 seconds
#
# Output: 6
# 10 Time taken: 1.78 seconds
#
# Output: 7
# 11 Time taken: 1.91 seconds
#
# Output: 6
# 12 Time taken: 2.05 seconds
#
# Output: 4
# 13 Time taken: 2.84 seconds
#
# Output: 4
# 14 Time taken: 1.99 seconds
#
# Output: 7
# 15 Time taken: 1.40 seconds
#
# Output: 6
# 16 Time taken: 2.50 seconds
#
# Output: 5
# 17 Time taken: 2.67 seconds
#
# Output: 3
# 18 Time taken: 1.28 seconds
#
# Output: 2
# 19 Time taken: 2.32 seconds
#
# Output: 7
# 20 Time taken: 2.11 seconds
#
# Output: 4
# 21 Time taken: 2.25 seconds
#
# Output: 5
# 22 Time taken: 2.58 seconds
#
# Output: 6
# 23 Time taken: 2.25 seconds
#
# Output: 5
# 24 Time taken: 2.15 seconds
#
# Output: 4
# 25 Time taken: 2.47 seconds
#
# Output: 7
# 26 Time taken: 2.13 seconds
#
# Output: 7
# 27 Time taken: 1.54 seconds
#
# Output: 6
# 28 Time taken: 2.29 seconds
#
# Output: 5
# 29 Time taken: 2.96 seconds
#
# Output: 6
# 30 Time taken: 3.39 seconds
#
# Output: 4
# 31 Time taken: 2.24 seconds
#
# Output: 6
# 32 Time taken: 1.76 seconds
#
# Output: 6
# 33 Time taken: 1.92 seconds
#
# Output: 6
# 34 Time taken: 1.28 seconds
#
# Output: 5
# 35 Time taken: 1.93 seconds
#
# Output: 5
# 36 Time taken: 2.20 seconds
#
# Output: 7
# 37 Time taken: 1.65 seconds
#
# Output: 5
# 38 Time taken: 1.70 seconds
#
# Output: 4
# 39 Time taken: 2.67 seconds
#
# Output: 7
# 40 Time taken: 2.24 seconds
#
# Output: 5
# 41 Time taken: 2.43 seconds
#
# Output: 4
# 42 Time taken: 2.43 seconds
#
# Output: 5
# 43 Time taken: 1.69 seconds
#
# Output: 6
# 44 Time taken: 2.77 seconds
#
# Output: 2
# 45 Time taken: 2.74 seconds
#
# Output: 6
# 46 Time taken: 3.58 seconds
#
# Output: 5
# 47 Time taken: 2.24 seconds
#
# Output: 7
# 48 Time taken: 2.07 seconds
#
# Output: 7
# 49 Time taken: 2.05 seconds
#
# Output: 6
# 50 Time taken: 2.70 seconds
#
# Output: 6
# 51 Time taken: 3.27 seconds
#
# Output: 6
# 52 Time taken: 1.51 seconds
#
# Output: 7
# 53 Time taken: 1.68 seconds
#
# Output: 5
# 54 Time taken: 1.95 seconds
#
# Output: 6
# 55 Time taken: 2.42 seconds
#
# Output: 6
# 56 Time taken: 2.05 seconds
#
# Output: 4
# 57 Time taken: 1.82 seconds
#
# Output: 5
# 58 Time taken: 1.96 seconds
#
# Output: 2
# 59 Time taken: 2.00 seconds
#
# Output: 4
# 60 Time taken: 1.56 seconds
#
# Output: 6
# 61 Time taken: 2.65 seconds
#
# Output: 6
# 62 Time taken: 3.58 seconds
#
# Output: 3
# 63 Time taken: 2.37 seconds
#
# Output: 6
# 64 Time taken: 2.71 seconds
#
# Output: 3
# 65 Time taken: 2.27 seconds
#
# Output: 4
# 66 Time taken: 2.92 seconds
#
# Output: 2
# 67 Time taken: 2.04 seconds
#
# Output: 6
# 68 Time taken: 2.52 seconds
#
# Output: 6
# 69 Time taken: 2.39 seconds
#
# Output: 3
# 70 Time taken: 2.68 seconds
#
# Output: 4
# 71 Time taken: 2.25 seconds
#
# Output: 4
# 72 Time taken: 3.17 seconds
#
# Output: 4
# 73 Time taken: 1.84 seconds
#
# Output: 5
# 74 Time taken: 2.33 seconds
#
# Output: 6
# 75 Time taken: 2.55 seconds
#
# Output: 4
# 76 Time taken: 2.32 seconds
#
# Output: 4
# 77 Time taken: 1.74 seconds
#
# Output: 6
# 78 Time taken: 1.92 seconds
#
# Output: 3
# 79 Time taken: 2.66 seconds
#
# Output: 6
# 80 Time taken: 3.36 seconds
#
# Output: 6
# 81 Time taken: 2.59 seconds
#
# Output: 6
# 82 Time taken: 3.18 seconds
#
# Output: 5
# 83 Time taken: 2.03 seconds
#
# Output: 5
# 84 Time taken: 2.34 seconds
#
# Output: 4
# 85 Time taken: 1.79 seconds
#
# Output: 5
# 86 Time taken: 1.45 seconds
#
# Output: 4
# 87 Time taken: 2.24 seconds
#
# Output: 4
# 88 Time taken: 1.90 seconds
#
# Output: 3
# 89 Time taken: 3.37 seconds
#
# Output: 5
# 90 Time taken: 2.23 seconds
#
# Output: 6
# 91 Time taken: 3.38 seconds
#
# Output: 5
# 92 Time taken: 1.85 seconds
#
# Output: 2
# 93 Time taken: 1.97 seconds
#
# Output: 5
# 94 Time taken: 3.12 seconds
#
# Output: 5
# 95 Time taken: 1.89 seconds
#
# Output: 4
# 96 Time taken: 3.26 seconds
#
# Output: 7
# 97 Time taken: 2.49 seconds
#
# Output: 6
# 98 Time taken: 1.57 seconds
#
# Output: 6
# 99 Time taken: 1.58 seconds
#
# Output: 2
# 100 Time taken: 1.72 seconds
#
# Output: 7
# 101 Time taken: 1.37 seconds
#
# Output: 3
# 102 Time taken: 1.74 seconds
#
# Output: 6
# 103 Time taken: 1.77 seconds
#
# Elapsed time for iteration 56: 238.96 seconds
#
# ### LLM-informant 57 ###
# Output: 6
# 0 Time taken: 2.09 seconds
#
# Output: 3
# 1 Time taken: 2.06 seconds
#
# Output: 5
# 2 Time taken: 2.02 seconds
#
# Output: 5
# 3 Time taken: 2.03 seconds
#
# Output: 4
# 4 Time taken: 2.11 seconds
#
# Output: 2
# 5 Time taken: 2.96 seconds
#
# Output: 6
# 6 Time taken: 2.06 seconds
#
# Output: 4
# 7 Time taken: 1.76 seconds
#
# Output: 6
# 8 Time taken: 3.31 seconds
#
# Output: 5
# 9 Time taken: 1.70 seconds
#
# Output: 6
# 10 Time taken: 2.16 seconds
#
# Output: 7
# 11 Time taken: 1.78 seconds
#
# Output: 6
# 12 Time taken: 2.36 seconds
#
# Output: 5
# 13 Time taken: 3.00 seconds
#
# Output: 5
# 14 Time taken: 2.43 seconds
#
# Output: 6
# 15 Time taken: 3.03 seconds
#
# Output: 5
# 16 Time taken: 4.46 seconds
#
# Output: 5
# 17 Time taken: 2.61 seconds
#
# Output: 5
# 18 Time taken: 2.31 seconds
#
# Output: 3
# 19 Time taken: 2.95 seconds
#
# Output: 7
# 20 Time taken: 2.35 seconds
#
# Output: 2
# 21 Time taken: 1.57 seconds
#
# Output: 5
# 22 Time taken: 2.31 seconds
#
# Output: 6
# 23 Time taken: 1.92 seconds
#
# Output: 5
# 24 Time taken: 1.75 seconds
#
# Output: 4
# 25 Time taken: 2.13 seconds
#
# Output: 7
# 26 Time taken: 2.08 seconds
#
# Output: 7
# 27 Time taken: 1.84 seconds
#
# Output: 5
# 28 Time taken: 3.41 seconds
#
# Output: 3
# 29 Time taken: 3.44 seconds
#
# Output: 6
# 30 Time taken: 2.18 seconds
#
# Output: 3
# 31 Time taken: 3.01 seconds
#
# Output: 6
# 32 Time taken: 2.55 seconds
#
# Output: 6
# 33 Time taken: 2.94 seconds
#
# Output: 6
# 34 Time taken: 1.84 seconds
#
# Output: 4
# 35 Time taken: 2.69 seconds
#
# Output: 5
# 36 Time taken: 1.76 seconds
#
# Output: 7
# 37 Time taken: 2.83 seconds
#
# Output: 4
# 38 Time taken: 2.58 seconds
#
# Output: 4
# 39 Time taken: 2.83 seconds
#
# Output: 6
# 40 Time taken: 2.73 seconds
#
# Output: 4
# 41 Time taken: 2.97 seconds
#
# Output: 4
# 42 Time taken: 1.45 seconds
#
# Output: 5
# 43 Time taken: 1.72 seconds
#
# Output: 6
# 44 Time taken: 1.67 seconds
#
# Output: 3
# 45 Time taken: 2.29 seconds
#
# Output: 6
# 46 Time taken: 2.58 seconds
#
# Output: 4
# 47 Time taken: 1.99 seconds
#
# Output: 6
# 48 Time taken: 3.50 seconds
#
# Output: 6
# 49 Time taken: 1.88 seconds
#
# Output: 6
# 50 Time taken: 2.56 seconds
#
# Output: 6
# 51 Time taken: 1.77 seconds
#
# Output: 7
# 52 Time taken: 2.07 seconds
#
# Output: 7
# 53 Time taken: 2.58 seconds
#
# Output: 4
# 54 Time taken: 2.44 seconds
#
# Output: 6
# 55 Time taken: 3.63 seconds
#
# Output: 6
# 56 Time taken: 2.67 seconds
#
# Output: 3
# 57 Time taken: 2.25 seconds
#
# Output: 5
# 58 Time taken: 2.61 seconds
#
# Output: 2
# 59 Time taken: 2.07 seconds
#
# Output: 4
# 60 Time taken: 2.76 seconds
#
# Output: 6
# 61 Time taken: 2.82 seconds
#
# Output: 5
# 62 Time taken: 3.55 seconds
#
# Output: 4
# 63 Time taken: 1.81 seconds
#
# Output: 6
# 64 Time taken: 1.95 seconds
#
# Output: 2
# 65 Time taken: 2.34 seconds
#
# Output: 4
# 66 Time taken: 1.78 seconds
#
# Output: 2
# 67 Time taken: 1.97 seconds
#
# Output: 6
# 68 Time taken: 2.29 seconds
#
# Output: 6
# 69 Time taken: 2.93 seconds
#
# Output: 1
# 70 Time taken: 2.31 seconds
#
# Output: 4
# 71 Time taken: 1.68 seconds
#
# Output: 5
# 72 Time taken: 3.12 seconds
#
# Output: 5
# 73 Time taken: 5.73 seconds
#
# Output: 6
# 74 Time taken: 1.56 seconds
#
# Output: 6
# 75 Time taken: 2.23 seconds
#
# Output: 4
# 76 Time taken: 2.03 seconds
#
# Output: 4
# 77 Time taken: 1.52 seconds
#
# Output: 7
# 78 Time taken: 2.12 seconds
#
# Output: 4
# 79 Time taken: 1.54 seconds
#
# Output: 5
# 80 Time taken: 2.12 seconds
#
# Output: 6
# 81 Time taken: 3.18 seconds
#
# Output: 6
# 82 Time taken: 2.19 seconds
#
# Output: 6
# 83 Time taken: 2.97 seconds
#
# Output: 5
# 84 Time taken: 2.87 seconds
#
# Output: 5
# 85 Time taken: 2.80 seconds
#
# Output: 5
# 86 Time taken: 2.50 seconds
#
# Output: 5
# 87 Time taken: 1.74 seconds
#
# Output: 4
# 88 Time taken: 2.15 seconds
#
# Output: 3
# 89 Time taken: 1.86 seconds
#
# Output: 5
# 90 Time taken: 1.77 seconds
#
# Output: 7
# 91 Time taken: 2.08 seconds
#
# Output: 5
# 92 Time taken: 2.08 seconds
#
# Output: 5
# 93 Time taken: 2.58 seconds
#
# Output: 5
# 94 Time taken: 1.69 seconds
#
# Output: 5
# 95 Time taken: 2.50 seconds
#
# Output: 4
# 96 Time taken: 2.05 seconds
#
# Output: 7
# 97 Time taken: 1.74 seconds
#
# Output: 6
# 98 Time taken: 2.15 seconds
#
# Output: 6
# 99 Time taken: 1.88 seconds
#
# Output: 1
# 100 Time taken: 3.00 seconds
#
# Output: 7
# 101 Time taken: 1.79 seconds
#
# Output: 4
# 102 Time taken: 2.91 seconds
#
# Output: 6
# 103 Time taken: 1.53 seconds
#
# Elapsed time for iteration 57: 246.81 seconds
#
# ### LLM-informant 58 ###
# Output: 6
# 0 Time taken: 3.05 seconds
#
# Output: 4
# 1 Time taken: 2.24 seconds
#
# Output: 5
# 2 Time taken: 4.83 seconds
#
# Output: 5
# 3 Time taken: 2.17 seconds
#
# Output: 3
# 4 Time taken: 3.12 seconds
#
# Output: 4
# 5 Time taken: 2.36 seconds
#
# Output: 5
# 6 Time taken: 1.64 seconds
#
# Output: 2
# 7 Time taken: 2.63 seconds
#
# Output: 5
# 8 Time taken: 6.29 seconds
#
# Output: 6
# 9 Time taken: 2.17 seconds
#
# Output: 6
# 10 Time taken: 2.35 seconds
#
# Output: 7
# 11 Time taken: 2.57 seconds
#
# Output: 6
# 12 Time taken: 1.97 seconds
#
# Output: 5
# 13 Time taken: 2.27 seconds
#
# Output: 5
# 14 Time taken: 2.12 seconds
#
# Output: 7
# 15 Time taken: 1.42 seconds
#
# Output: 5
# 16 Time taken: 1.99 seconds
#
# Output: 4
# 17 Time taken: 2.30 seconds
#
# Output: 4
# 18 Time taken: 2.84 seconds
#
# Output: 2
# 19 Time taken: 1.95 seconds
#
# Output: 6
# 20 Time taken: 2.49 seconds
#
# Output: 3
# 21 Time taken: 3.04 seconds
#
# Output: 5
# 22 Time taken: 3.38 seconds
#
# Output: 6
# 23 Time taken: 2.81 seconds
#
# Output: 4
# 24 Time taken: 1.45 seconds
#
# Output: 4
# 25 Time taken: 2.50 seconds
#
# Output: 7
# 26 Time taken: 1.90 seconds
#
# Output: 7
# 27 Time taken: 1.95 seconds
#
# Output: 6
# 28 Time taken: 3.75 seconds
#
# Output: 5
# 29 Time taken: 2.91 seconds
#
# Output: 6
# 30 Time taken: 2.31 seconds
#
# Output: 3
# 31 Time taken: 2.90 seconds
#
# Output: 5
# 32 Time taken: 1.77 seconds
#
# Output: 6
# 33 Time taken: 1.94 seconds
#
# Output: 6
# 34 Time taken: 2.59 seconds
#
# Output: 6
# 35 Time taken: 2.12 seconds
#
# Output: 5
# 36 Time taken: 2.68 seconds
#
# Output: 6
# 37 Time taken: 2.11 seconds
#
# Output: 4
# 38 Time taken: 3.14 seconds
#
# Output: 4
# 39 Time taken: 3.65 seconds
#
# Output: 6
# 40 Time taken: 2.25 seconds
#
# Output: 4
# 41 Time taken: 2.11 seconds
#
# Output: 4
# 42 Time taken: 2.51 seconds
#
# Output: 5
# 43 Time taken: 2.86 seconds
#
# Output: 6
# 44 Time taken: 1.99 seconds
#
# Output: 4
# 45 Time taken: 1.80 seconds
#
# Output: 6
# 46 Time taken: 1.62 seconds
#
# Output: 4
# 47 Time taken: 1.68 seconds
#
# Output: 7
# 48 Time taken: 1.36 seconds
#
# Output: 6
# 49 Time taken: 2.47 seconds
#
# Output: 6
# 50 Time taken: 2.14 seconds
#
# Output: 6
# 51 Time taken: 1.24 seconds
#
# Output: 7
# 52 Time taken: 1.18 seconds
#
# Output: 7
# 53 Time taken: 1.07 seconds
#
# Output: 4
# 54 Time taken: 4.80 seconds
#
# Output: 6
# 55 Time taken: 1.97 seconds
#
# Output: 6
# 56 Time taken: 3.15 seconds
#
# Output: 4
# 57 Time taken: 3.21 seconds
#
# Output: 6
# 58 Time taken: 2.02 seconds
#
# Output: 2
# 59 Time taken: 2.46 seconds
#
# Output: 4
# 60 Time taken: 2.51 seconds
#
# Output: 5
# 61 Time taken: 2.71 seconds
#
# Output: 5
# 62 Time taken: 1.71 seconds
#
# Output: 4
# 63 Time taken: 2.21 seconds
#
# Output: 6
# 64 Time taken: 2.39 seconds
#
# Output: 2
# 65 Time taken: 1.67 seconds
#
# Output: 5
# 66 Time taken: 2.13 seconds
#
# Output: 2
# 67 Time taken: 2.51 seconds
#
# Output: 6
# 68 Time taken: 2.44 seconds
#
# Output: 6
# 69 Time taken: 1.72 seconds
#
# Output: 2
# 70 Time taken: 4.11 seconds
#
# Output: 3
# 71 Time taken: 2.26 seconds
#
# Output: 5
# 72 Time taken: 2.93 seconds
#
# Output: 5
# 73 Time taken: 1.93 seconds
#
# Output: 5
# 74 Time taken: 1.60 seconds
#
# Output: 7
# 75 Time taken: 2.04 seconds
#
# Output: 4
# 76 Time taken: 3.10 seconds
#
# Output: 5
# 77 Time taken: 1.92 seconds
#
# Output: 6
# 78 Time taken: 2.96 seconds
#
# Output: 2
# 79 Time taken: 2.29 seconds
#
# Output: 6
# 80 Time taken: 2.59 seconds
#
# Output: 6
# 81 Time taken: 2.44 seconds
#
# Output: 6
# 82 Time taken: 3.10 seconds
#
# Output: 5
# 83 Time taken: 2.63 seconds
#
# Output: 5
# 84 Time taken: 3.93 seconds
#
# Output: 5
# 85 Time taken: 2.15 seconds
#
# Output: 4
# 86 Time taken: 2.93 seconds
#
# Output: 5
# 87 Time taken: 2.92 seconds
#
# Output: 5
# 88 Time taken: 1.85 seconds
#
# Output: 3
# 89 Time taken: 2.21 seconds
#
# Output: 2
# 90 Time taken: 1.71 seconds
#
# Output: 7
# 91 Time taken: 2.19 seconds
#
# Output: 5
# 92 Time taken: 1.39 seconds
#
# Output: 4
# 93 Time taken: 2.04 seconds
#
# Output: 4
# 94 Time taken: 3.15 seconds
#
# Output: 5
# 95 Time taken: 1.40 seconds
#
# Output: 5
# 96 Time taken: 2.61 seconds
#
# Output: 7
# 97 Time taken: 2.66 seconds
#
# Output: 6
# 98 Time taken: 1.78 seconds
#
# Output: 6
# 99 Time taken: 3.16 seconds
#
# Output: 1
# 100 Time taken: 2.10 seconds
#
# Output: 7
# 101 Time taken: 2.47 seconds
#
# Output: 3
# 102 Time taken: 2.42 seconds
#
# Output: 6
# 103 Time taken: 2.36 seconds
#
# Elapsed time for iteration 58: 252.94 seconds
#
# ### LLM-informant 59 ###
# Output: 6
# 0 Time taken: 3.25 seconds
#
# Output: 4
# 1 Time taken: 2.41 seconds
#
# Output: 6
# 2 Time taken: 2.02 seconds
#
# Output: 4
# 3 Time taken: 2.48 seconds
#
# Output: 2
# 4 Time taken: 3.01 seconds
#
# Output: 4
# 5 Time taken: 1.68 seconds
#
# Output: 5
# 6 Time taken: 2.48 seconds
#
# Output: 5
# 7 Time taken: 1.78 seconds
#
# Output: 5
# 8 Time taken: 3.28 seconds
#
# Output: 6
# 9 Time taken: 2.52 seconds
#
# Output: 6
# 10 Time taken: 2.77 seconds
#
# Output: 7
# 11 Time taken: 2.42 seconds
#
# Output: 6
# 12 Time taken: 2.76 seconds
#
# Output: 5
# 13 Time taken: 1.97 seconds
#
# Output: 4
# 14 Time taken: 2.49 seconds
#
# Output: 7
# 15 Time taken: 1.79 seconds
#
# Output: 5
# 16 Time taken: 2.52 seconds
#
# Output: 6
# 17 Time taken: 3.04 seconds
#
# Output: 4
# 18 Time taken: 1.77 seconds
#
# Output: 2
# 19 Time taken: 2.15 seconds
#
# Output: 7
# 20 Time taken: 4.26 seconds
#
# Output: 3
# 21 Time taken: 3.41 seconds
#
# Output: 5
# 22 Time taken: 2.57 seconds
#
# Output: 5
# 23 Time taken: 2.14 seconds
#
# Output: 4
# 24 Time taken: 2.88 seconds
#
# Output: 5
# 25 Time taken: 2.40 seconds
#
# Output: 7
# 26 Time taken: 1.67 seconds
#
# Output: 7
# 27 Time taken: 2.09 seconds
#
# Output: 5
# 28 Time taken: 1.73 seconds
#
# Output: 5
# 29 Time taken: 2.30 seconds
#
# Output: 6
# 30 Time taken: 1.67 seconds
#
# Output: 3
# 31 Time taken: 2.77 seconds
#
# Output: 4
# 32 Time taken: 3.21 seconds
#
# Output: 6
# 33 Time taken: 2.58 seconds
#
# Output: 6
# 34 Time taken: 2.69 seconds
#
# Output: 5
# 35 Time taken: 1.78 seconds
#
# Output: 5
# 36 Time taken: 2.86 seconds
#
# Output: 7
# 37 Time taken: 3.33 seconds
#
# Output: 5
# 38 Time taken: 3.08 seconds
#
# Output: 4
# 39 Time taken: 2.39 seconds
#
# Output: 6
# 40 Time taken: 3.40 seconds
#
# Output: 4
# 41 Time taken: 1.92 seconds
#
# Output: 4
# 42 Time taken: 1.97 seconds
#
# Output: 5
# 43 Time taken: 1.87 seconds
#
# Output: 6
# 44 Time taken: 2.78 seconds
#
# Output: 2
# 45 Time taken: 2.29 seconds
#
# Output: 6
# 46 Time taken: 2.03 seconds
#
# Output: 4
# 47 Time taken: 1.92 seconds
#
# Output: 6
# 48 Time taken: 1.63 seconds
#
# Output: 6
# 49 Time taken: 2.15 seconds
#
# Output: 6
# 50 Time taken: 2.30 seconds
#
# Output: 6
# 51 Time taken: 3.08 seconds
#
# Output: 7
# 52 Time taken: 2.13 seconds
#
# Output: 7
# 53 Time taken: 1.86 seconds
#
# Output: 5
# 54 Time taken: 2.07 seconds
#
# Output: 7
# 55 Time taken: 2.79 seconds
#
# Output: 7
# 56 Time taken: 2.41 seconds
#
# Output: 3
# 57 Time taken: 2.29 seconds
#
# Output: 6
# 58 Time taken: 2.17 seconds
#
# Output: 2
# 59 Time taken: 2.08 seconds
#
# Output: 5
# 60 Time taken: 1.67 seconds
#
# Output: 6
# 61 Time taken: 2.73 seconds
#
# Output: 5
# 62 Time taken: 2.01 seconds
#
# Output: 4
# 63 Time taken: 1.91 seconds
#
# Output: 6
# 64 Time taken: 2.31 seconds
#
# Output: 2
# 65 Time taken: 2.03 seconds
#
# Output: 3
# 66 Time taken: 2.73 seconds
#
# Output: 2
# 67 Time taken: 2.07 seconds
#
# Output: 6
# 68 Time taken: 1.68 seconds
#
# Output: 6
# 69 Time taken: 2.38 seconds
#
# Output: 3
# 70 Time taken: 2.49 seconds
#
# Output: 2
# 71 Time taken: 3.20 seconds
#
# Output: 5
# 72 Time taken: 2.18 seconds
#
# Output: 5
# 73 Time taken: 2.47 seconds
#
# Output: 5
# 74 Time taken: 2.31 seconds
#
# Output: 7
# 75 Time taken: 3.27 seconds
#
# Output: 5
# 76 Time taken: 2.39 seconds
#
# Output: 4
# 77 Time taken: 1.90 seconds
#
# Output: 6
# 78 Time taken: 1.64 seconds
#
# Output: 2
# 79 Time taken: 2.19 seconds
#
# Output: 5
# 80 Time taken: 2.39 seconds
#
# Output: 6
# 81 Time taken: 3.16 seconds
#
# Output: 6
# 82 Time taken: 1.99 seconds
#
# Output: 6
# 83 Time taken: 3.25 seconds
#
# Output: 5
# 84 Time taken: 1.74 seconds
#
# Output: 5
# 85 Time taken: 3.44 seconds
#
# Output: 4
# 86 Time taken: 1.90 seconds
#
# Output: 3
# 87 Time taken: 2.54 seconds
#
# Output: 4
# 88 Time taken: 2.92 seconds
#
# Output: 3
# 89 Time taken: 1.98 seconds
#
# Output: 5
# 90 Time taken: 1.57 seconds
#
# Output: 7
# 91 Time taken: 2.00 seconds
#
# Output: 5
# 92 Time taken: 3.19 seconds
#
# Output: 3
# 93 Time taken: 3.18 seconds
#
# Output: 5
# 94 Time taken: 2.66 seconds
#
# Output: 5
# 95 Time taken: 1.88 seconds
#
# Output: 5
# 96 Time taken: 2.51 seconds
#
# Output: 7
# 97 Time taken: 1.37 seconds
#
# Output: 6
# 98 Time taken: 3.84 seconds
#
# Output: 6
# 99 Time taken: 2.77 seconds
#
# Output: 2
# 100 Time taken: 2.94 seconds
#
# Output: 7
# 101 Time taken: 3.81 seconds
#
# Output: 3
# 102 Time taken: 2.74 seconds
#
# Output: 6
# 103 Time taken: 2.15 seconds
#
# Elapsed time for iteration 59: 252.98 seconds
#
# ### LLM-informant 60 ###
# Output: 6
# 0 Time taken: 3.40 seconds
#
# Output: 4
# 1 Time taken: 2.52 seconds
#
# Output: 5
# 2 Time taken: 2.83 seconds
#
# Output: 5
# 3 Time taken: 2.73 seconds
#
# Output: 4
# 4 Time taken: 2.57 seconds
#
# Output: 4
# 5 Time taken: 3.75 seconds
#
# Output: 5
# 6 Time taken: 2.43 seconds
#
# Output: 4
# 7 Time taken: 2.68 seconds
#
# Output: 6
# 8 Time taken: 3.32 seconds
#
# Output: 5
# 9 Time taken: 3.81 seconds
#
# Output: 6
# 10 Time taken: 2.03 seconds
#
# Output: 7
# 11 Time taken: 2.94 seconds
#
# Output: 4
# 12 Time taken: 2.65 seconds
#
# Output: 4
# 13 Time taken: 2.78 seconds
#
# Output: 4
# 14 Time taken: 2.05 seconds
#
# Output: 7
# 15 Time taken: 2.10 seconds
#
# Output: 4
# 16 Time taken: 3.28 seconds
#
# Output: 5
# 17 Time taken: 3.74 seconds
#
# Output: 4
# 18 Time taken: 2.74 seconds
#
# Output: 2
# 19 Time taken: 2.05 seconds
#
# Output: 6
# 20 Time taken: 2.79 seconds
#
# Output: 3
# 21 Time taken: 3.05 seconds
#
# Output: 5
# 22 Time taken: 2.33 seconds
#
# Output: 5
# 23 Time taken: 3.43 seconds
#
# Output: 3
# 24 Time taken: 1.76 seconds
#
# Output: 4
# 25 Time taken: 4.33 seconds
#
# Output: 7
# 26 Time taken: 3.15 seconds
#
# Output: 7
# 27 Time taken: 1.62 seconds
#
# Output: 5
# 28 Time taken: 2.47 seconds
#
# Output: 4
# 29 Time taken: 3.98 seconds
#
# Output: 6
# 30 Time taken: 2.26 seconds
#
# Output: 4
# 31 Time taken: 2.84 seconds
#
# Output: 5
# 32 Time taken: 2.56 seconds
#
# Output: 5
# 33 Time taken: 3.54 seconds
#
# Output: 6
# 34 Time taken: 2.62 seconds
#
# Output: 5
# 35 Time taken: 2.40 seconds
#
# Output: 5
# 36 Time taken: 2.05 seconds
#
# Output: 6
# 37 Time taken: 2.95 seconds
#
# Output: 4
# 38 Time taken: 2.73 seconds
#
# Output: 5
# 39 Time taken: 2.10 seconds
#
# Output: 6
# 40 Time taken: 3.12 seconds
#
# Output: 5
# 41 Time taken: 2.61 seconds
#
# Output: 3
# 42 Time taken: 3.05 seconds
#
# Output: 5
# 43 Time taken: 2.34 seconds
#
# Output: 7
# 44 Time taken: 2.94 seconds
#
# Output: 4
# 45 Time taken: 2.88 seconds
#
# Output: 6
# 46 Time taken: 1.70 seconds
#
# Output: 4
# 47 Time taken: 2.65 seconds
#
# Output: 7
# 48 Time taken: 1.66 seconds
#
# Output: 6
# 49 Time taken: 2.16 seconds
#
# Output: 7
# 50 Time taken: 4.29 seconds
#
# Output: 6
# 51 Time taken: 3.41 seconds
#
# Output: 7
# 52 Time taken: 3.12 seconds
#
# Output: 7
# 53 Time taken: 2.59 seconds
#
# Output: 5
# 54 Time taken: 2.35 seconds
#
# Output: 6
# 55 Time taken: 3.30 seconds
#
# Output: 6
# 56 Time taken: 3.41 seconds
#
# Output: 4
# 57 Time taken: 3.09 seconds
#
# Output: 5
# 58 Time taken: 3.61 seconds
#
# Output: 3
# 59 Time taken: 3.65 seconds
#
# Output: 4
# 60 Time taken: 1.92 seconds
#
# Output: 6
# 61 Time taken: 1.97 seconds
#
# Output: 6
# 62 Time taken: 1.95 seconds
#
# Output: 3
# 63 Time taken: 3.14 seconds
#
# Output: 6
# 64 Time taken: 3.59 seconds
#
# Output: 3
# 65 Time taken: 4.29 seconds
#
# Output: 3
# 66 Time taken: 2.47 seconds
#
# Output: 3
# 67 Time taken: 3.97 seconds
#
# Output: 6
# 68 Time taken: 3.10 seconds
#
# Output: 6
# 69 Time taken: 2.32 seconds
#
# Output: 4
# 70 Time taken: 3.85 seconds
#
# Output: 4
# 71 Time taken: 2.68 seconds
#
# Output: 4
# 72 Time taken: 2.80 seconds
#
# Output: 4
# 73 Time taken: 2.41 seconds
#
# Output: 5
# 74 Time taken: 4.01 seconds
#
# Output: 7
# 75 Time taken: 2.16 seconds
#
# Output: 5
# 76 Time taken: 3.90 seconds
#
# Output: 4
# 77 Time taken: 2.03 seconds
#
# Output: 6
# 78 Time taken: 2.13 seconds
#
# Output: 2
# 79 Time taken: 3.41 seconds
#
# Output: 6
# 80 Time taken: 2.53 seconds
#
# Output: 6
# 81 Time taken: 2.19 seconds
#
# Output: 6
# 82 Time taken: 2.77 seconds
#
# Output: 6
# 83 Time taken: 4.29 seconds
#
# Output: 5
# 84 Time taken: 3.71 seconds
#
# Output: 5
# 85 Time taken: 2.08 seconds
#
# Output: 4
# 86 Time taken: 2.90 seconds
#
# Output: 5
# 87 Time taken: 2.59 seconds
#
# Output: 4
# 88 Time taken: 4.07 seconds
#
# Output: 3
# 89 Time taken: 4.84 seconds
#
# Output: 5
# 90 Time taken: 2.94 seconds
#
# Output: 7
# 91 Time taken: 2.19 seconds
#
# Output: 5
# 92 Time taken: 2.53 seconds
#
# Output: 4
# 93 Time taken: 2.71 seconds
#
# Output: 5
# 94 Time taken: 4.41 seconds
#
# Output: 5
# 95 Time taken: 2.48 seconds
#
# Output: 5
# 96 Time taken: 2.03 seconds
#
# Output: 6
# 97 Time taken: 4.14 seconds
#
# Output: 6
# 98 Time taken: 2.43 seconds
#
# Output: 6
# 99 Time taken: 1.58 seconds
#
# Output: 1
# 100 Time taken: 2.55 seconds
#
# Output: 7
# 101 Time taken: 4.86 seconds
#
# Output: 4
# 102 Time taken: 2.60 seconds
#
# Output: 6
# 103 Time taken: 1.97 seconds
#
# Elapsed time for iteration 60: 298.77 seconds
#
# ### LLM-informant 61 ###
# Output: 6
# 0 Time taken: 2.26 seconds
#
# Output: 3
# 1 Time taken: 2.16 seconds
#
# Output: 4
# 2 Time taken: 2.90 seconds
#
# Output: 5
# 3 Time taken: 4.14 seconds
#
# Output: 3
# 4 Time taken: 4.30 seconds
#
# Output: 6
# 5 Time taken: 1.96 seconds
#
# Output: 5
# 6 Time taken: 3.33 seconds
#
# Output: 4
# 7 Time taken: 2.79 seconds
#
# Output: 5
# 8 Time taken: 2.64 seconds
#
# Output: 6
# 9 Time taken: 2.32 seconds
#
# Output: 6
# 10 Time taken: 3.19 seconds
#
# Output: 7
# 11 Time taken: 2.67 seconds
#
# Output: 5
# 12 Time taken: 2.97 seconds
#
# Output: 5
# 13 Time taken: 3.22 seconds
#
# Output: 4
# 14 Time taken: 3.67 seconds
#
# Output: 7
# 15 Time taken: 2.45 seconds
#
# Output: 4
# 16 Time taken: 3.37 seconds
#
# Output: 5
# 17 Time taken: 3.66 seconds
#
# Output: 4
# 18 Time taken: 2.09 seconds
#
# Output: 2
# 19 Time taken: 2.96 seconds
#
# Output: 7
# 20 Time taken: 3.20 seconds
#
# Output: 2
# 21 Time taken: 3.29 seconds
#
# Output: 5
# 22 Time taken: 3.61 seconds
#
# Output: 6
# 23 Time taken: 3.37 seconds
#
# Output: 4
# 24 Time taken: 3.08 seconds
#
# Output: 5
# 25 Time taken: 3.01 seconds
#
# Output: 7
# 26 Time taken: 2.51 seconds
#
# Output: 7
# 27 Time taken: 3.59 seconds
#
# Output: 4
# 28 Time taken: 3.18 seconds
#
# Output: 4
# 29 Time taken: 2.68 seconds
#
# Output: 6
# 30 Time taken: 2.56 seconds
#
# Output: 4
# 31 Time taken: 3.06 seconds
#
# Output: 4
# 32 Time taken: 5.10 seconds
#
# Output: 6
# 33 Time taken: 2.32 seconds
#
# Output: 6
# 34 Time taken: 2.26 seconds
#
# Output: 5
# 35 Time taken: 3.48 seconds
#
# Output: 6
# 36 Time taken: 2.99 seconds
#
# Output: 7
# 37 Time taken: 2.84 seconds
#
# Output: 5
# 38 Time taken: 3.16 seconds
#
# Output: 5
# 39 Time taken: 2.47 seconds
#
# Output: 7
# 40 Time taken: 3.32 seconds
#
# Output: 5
# 41 Time taken: 2.77 seconds
#
# Output: 4
# 42 Time taken: 2.27 seconds
#
# Output: 5
# 43 Time taken: 2.16 seconds
#
# Output: 6
# 44 Time taken: 1.59 seconds
#
# Output: 2
# 45 Time taken: 3.04 seconds
#
# Output: 6
# 46 Time taken: 1.70 seconds
#
# Output: 4
# 47 Time taken: 2.63 seconds
#
# Output: 7
# 48 Time taken: 3.97 seconds
#
# Output: 7
# 49 Time taken: 3.39 seconds
#
# Output: 7
# 50 Time taken: 2.53 seconds
#
# Output: 6
# 51 Time taken: 1.83 seconds
#
# Output: 7
# 52 Time taken: 2.99 seconds
#
# Output: 7
# 53 Time taken: 1.46 seconds
#
# Output: 4
# 54 Time taken: 2.97 seconds
#
# Output: 6
# 55 Time taken: 2.00 seconds
#
# Output: 6
# 56 Time taken: 1.99 seconds
#
# Output: 4
# 57 Time taken: 1.99 seconds
#
# Output: 6
# 58 Time taken: 2.89 seconds
#
# Output: 2
# 59 Time taken: 3.38 seconds
#
# Output: 4
# 60 Time taken: 2.26 seconds
#
# Output: 6
# 61 Time taken: 2.35 seconds
#
# Output: 5
# 62 Time taken: 1.66 seconds
#
# Output: 3
# 63 Time taken: 2.27 seconds
#
# Output: 6
# 64 Time taken: 3.03 seconds
#
# Output: 3
# 65 Time taken: 3.03 seconds
#
# Output: 3
# 66 Time taken: 3.45 seconds
#
# Output: 2
# 67 Time taken: 3.10 seconds
#
# Output: 6
# 68 Time taken: 4.80 seconds
#
# Output: 6
# 69 Time taken: 2.70 seconds
#
# Output: 3
# 70 Time taken: 1.92 seconds
#
# Output: 5
# 71 Time taken: 3.21 seconds
#
# Output: 5
# 72 Time taken: 2.13 seconds
#
# Output: 5
# 73 Time taken: 2.61 seconds
#
# Output: 4
# 74 Time taken: 3.03 seconds
#
# Output: 6
# 75 Time taken: 2.45 seconds
#
# Output: 5
# 76 Time taken: 2.33 seconds
#
# Output: 5
# 77 Time taken: 1.63 seconds
#
# Output: 7
# 78 Time taken: 1.93 seconds
#
# Output: 4
# 79 Time taken: 3.19 seconds
#
# Output: 6
# 80 Time taken: 3.86 seconds
#
# Output: 6
# 81 Time taken: 2.18 seconds
#
# Output: 5
# 82 Time taken: 2.64 seconds
#
# Output: 5
# 83 Time taken: 3.65 seconds
#
# Output: 5
# 84 Time taken: 1.45 seconds
#
# Output: 5
# 85 Time taken: 3.41 seconds
#
# Output: 5
# 86 Time taken: 1.99 seconds
#
# Output: 5
# 87 Time taken: 2.70 seconds
#
# Output: 5
# 88 Time taken: 2.46 seconds
#
# Output: 2
# 89 Time taken: 2.77 seconds
#
# Output: 5
# 90 Time taken: 2.84 seconds
#
# Output: 7
# 91 Time taken: 1.78 seconds
#
# Output: 5
# 92 Time taken: 2.40 seconds
#
# Output: 3
# 93 Time taken: 2.80 seconds
#
# Output: 5
# 94 Time taken: 2.46 seconds
#
# Output: 6
# 95 Time taken: 2.08 seconds
#
# Output: 4
# 96 Time taken: 2.96 seconds
#
# Output: 7
# 97 Time taken: 2.14 seconds
#
# Output: 6
# 98 Time taken: 1.86 seconds
#
# Output: 7
# 99 Time taken: 2.98 seconds
#
# Output: 3
# 100 Time taken: 3.01 seconds
#
# Output: 7
# 101 Time taken: 2.54 seconds
#
# Output: 2
# 102 Time taken: 3.15 seconds
#
# Output: 6
# 103 Time taken: 3.18 seconds
#
# Elapsed time for iteration 61: 288.08 seconds
#
# ### LLM-informant 62 ###
# Output: 6
# 0 Time taken: 1.97 seconds
#
# Output: 4
# 1 Time taken: 2.11 seconds
#
# Output: 5
# 2 Time taken: 2.78 seconds
#
# Output: 4
# 3 Time taken: 1.80 seconds
#
# Output: 2
# 4 Time taken: 3.68 seconds
#
# Output: 3
# 5 Time taken: 4.11 seconds
#
# Output: 5
# 6 Time taken: 3.14 seconds
#
# Output: 4
# 7 Time taken: 1.78 seconds
#
# Output: 5
# 8 Time taken: 3.22 seconds
#
# Output: 6
# 9 Time taken: 2.07 seconds
#
# Output: 6
# 10 Time taken: 2.31 seconds
#
# Output: 7
# 11 Time taken: 2.07 seconds
#
# Output: 5
# 12 Time taken: 2.12 seconds
#
# Output: 5
# 13 Time taken: 2.65 seconds
#
# Output: 4
# 14 Time taken: 2.30 seconds
#
# Output: 7
# 15 Time taken: 3.58 seconds
#
# Output: 5
# 16 Time taken: 3.28 seconds
#
# Output: 5
# 17 Time taken: 2.90 seconds
#
# Output: 5
# 18 Time taken: 2.49 seconds
#
# Output: 2
# 19 Time taken: 1.68 seconds
#
# Output: 6
# 20 Time taken: 2.80 seconds
#
# Output: 2
# 21 Time taken: 3.10 seconds
#
# Output: 6
# 22 Time taken: 1.75 seconds
#
# Output: 6
# 23 Time taken: 1.87 seconds
#
# Output: 4
# 24 Time taken: 2.51 seconds
#
# Output: 5
# 25 Time taken: 2.01 seconds
#
# Output: 7
# 26 Time taken: 2.72 seconds
#
# Output: 6
# 27 Time taken: 2.28 seconds
#
# Output: 5
# 28 Time taken: 2.69 seconds
#
# Output: 5
# 29 Time taken: 2.23 seconds
#
# Output: 6
# 30 Time taken: 2.78 seconds
#
# Output: 4
# 31 Time taken: 2.71 seconds
#
# Output: 6
# 32 Time taken: 2.13 seconds
#
# Output: 6
# 33 Time taken: 2.94 seconds
#
# Output: 6
# 34 Time taken: 3.29 seconds
#
# Output: 5
# 35 Time taken: 1.87 seconds
#
# Output: 5
# 36 Time taken: 2.38 seconds
#
# Output: 7
# 37 Time taken: 3.49 seconds
#
# Output: 5
# 38 Time taken: 2.07 seconds
#
# Output: 5
# 39 Time taken: 2.52 seconds
#
# Output: 6
# 40 Time taken: 2.48 seconds
#
# Output: 4
# 41 Time taken: 1.93 seconds
#
# Output: 5
# 42 Time taken: 2.23 seconds
#
# Output: 5
# 43 Time taken: 4.50 seconds
#
# Output: 6
# 44 Time taken: 3.40 seconds
#
# Output: 4
# 45 Time taken: 2.04 seconds
#
# Output: 6
# 46 Time taken: 2.18 seconds
#
# Output: 4
# 47 Time taken: 2.44 seconds
#
# Output: 7
# 48 Time taken: 2.31 seconds
#
# Output: 7
# 49 Time taken: 1.94 seconds
#
# Output: 6
# 50 Time taken: 3.17 seconds
#
# Output: 6
# 51 Time taken: 3.38 seconds
#
# Output: 7
# 52 Time taken: 1.80 seconds
#
# Output: 7
# 53 Time taken: 2.50 seconds
#
# Output: 5
# 54 Time taken: 4.52 seconds
#
# Output: 6
# 55 Time taken: 4.19 seconds
#
# Output: 6
# 56 Time taken: 2.42 seconds
#
# Output: 4
# 57 Time taken: 2.41 seconds
#
# Output: 5
# 58 Time taken: 2.51 seconds
#
# Output: 2
# 59 Time taken: 3.47 seconds
#
# Output: 4
# 60 Time taken: 2.82 seconds
#
# Output: 5
# 61 Time taken: 2.45 seconds
#
# Output: 5
# 62 Time taken: 3.04 seconds
#
# Output: 4
# 63 Time taken: 1.93 seconds
#
# Output: 6
# 64 Time taken: 3.63 seconds
#
# Output: 4
# 65 Time taken: 2.15 seconds
#
# Output: 6
# 66 Time taken: 1.71 seconds
#
# Output: 2
# 67 Time taken: 2.63 seconds
#
# Output: 6
# 68 Time taken: 4.19 seconds
#
# Output: 6
# 69 Time taken: 2.02 seconds
#
# Output: 2
# 70 Time taken: 1.88 seconds
#
# Output: 4
# 71 Time taken: 2.45 seconds
#
# Output: 5
# 72 Time taken: 2.15 seconds
#
# Output: 5
# 73 Time taken: 2.81 seconds
#
# Output: 5
# 74 Time taken: 1.75 seconds
#
# Output: 6
# 75 Time taken: 2.07 seconds
#
# Output: 4
# 76 Time taken: 5.14 seconds
#
# Output: 5
# 77 Time taken: 2.55 seconds
#
# Output: 6
# 78 Time taken: 2.27 seconds
#
# Output: 4
# 79 Time taken: 2.09 seconds
#
# Output: 6
# 80 Time taken: 2.66 seconds
#
# Output: 6
# 81 Time taken: 3.42 seconds
#
# Output: 6
# 82 Time taken: 1.86 seconds
#
# Output: 5
# 83 Time taken: 4.07 seconds
#
# Output: 5
# 84 Time taken: 2.36 seconds
#
# Output: 5
# 85 Time taken: 2.53 seconds
#
# Output: 4
# 86 Time taken: 2.64 seconds
#
# Output: 2
# 87 Time taken: 2.27 seconds
#
# Output: 4
# 88 Time taken: 3.87 seconds
#
# Output: 3
# 89 Time taken: 2.90 seconds
#
# Output: 5
# 90 Time taken: 2.34 seconds
#
# Output: 7
# 91 Time taken: 2.55 seconds
#
# Output: 5
# 92 Time taken: 2.59 seconds
#
# Output: 4
# 93 Time taken: 3.38 seconds
#
# Output: 5
# 94 Time taken: 3.46 seconds
#
# Output: 5
# 95 Time taken: 2.46 seconds
#
# Output: 5
# 96 Time taken: 3.04 seconds
#
# Output: 7
# 97 Time taken: 1.89 seconds
#
# Output: 6
# 98 Time taken: 3.64 seconds
#
# Output: 6
# 99 Time taken: 2.44 seconds
#
# Output: 2
# 100 Time taken: 3.01 seconds
#
# Output: 7
# 101 Time taken: 3.17 seconds
#
# Output: 4
# 102 Time taken: 2.81 seconds
#
# Output: 7
# 103 Time taken: 3.13 seconds
#
# Elapsed time for iteration 62: 278.21 seconds
#
# {51: {0: {'Prompt': "Nous allons vous présenter deux mots separées de un -. Votre tâche consiste à réfléchir au sens de ces mots et indiquer sur une échelle en 7 points à quel point vous considérez que ces deux mots sont similaires sémantiquement (qu’ils ont le même sens). Si vous considérez que les deux mots de la paire sont très similaires sémantiquement, vous pouvez choisir le point 7 (« tout à fait similaires »). Si vous considérez que les deux mots de la paire sont très différents sémantiquement, vous pouvez choisir le point 1 (« pas du tout similaires »). Vous pouvez utiliser tous les points de l’échelle. Par exemple, si la paire présentée est professeur – enseignant, vous pouvez choisir le point 6. Si la paire présentée est lune – route, vous pouvez choisir le point 1. N’hésitez pas à utiliser toute la gamme des chiffres comprise entre 1 et 7 mais ne vous préoccupez pas du nombre de fois que vous avez utilisé un chiffre en particulier tant qu’il fait référence à votre véritable jugement. Il n'y a pas de bonne ou de mauvaise réponse. Veuillez donc répondre le plus spontanément possible. Ne donnez pas d'éxplications. Les mots sont: 'mutinerie-révolte'", 'Antwort': '7', 'Zeit': 2.3456521034240723}, 1: {'Prompt': "Nous allons vous présenter deux mots separées de un -. Votre tâche consiste à réfléchir au sens de ces mots et indiquer sur une échelle en 7 points à quel point vous considérez que ces deux mots sont similaires sémantiquement (qu’ils ont le même sens). Si vous considérez que les deux mots de la paire sont très similaires sémantiquement, vous pouvez choisir le point 7 (« tout à fait similaires »). Si vous considérez que les deux mots de la paire sont très différents sémantiquement, vous pouvez choisir le point 1 (« pas du tout similaires »). Vous pouvez utiliser tous les points de l’échelle. Par exemple, si la paire présentée est professeur – enseignant, vous pouvez choisir le point 6. Si la paire présentée est lune – route, vous pouvez choisir le point 1. N’hésitez pas à utiliser toute la gamme des chiffres comprise entre 1 et 7 mais ne vous préoccupez pas du nombre de fois que vous avez utilisé un chiffre en particulier tant qu’il fait référence à votre véritable jugement. Il n'y a pas de bonne ou de mauvaise réponse. Veuillez donc répondre le plus spontanément possible. Ne donnez pas d'éxplications. Les mots sont: 'nager-flotter'", 'Antwort': '3', 'Zeit': 2.5001041889190674}, 2: {'Prompt': "Nous allons vous présenter deux mots separées de un -. Votre tâche consiste à réfléchir au sens de ces mots et indiquer sur une échelle en 7 points à quel point vous considérez que ces deux mots sont similaires sémantiquement (qu’ils ont le même sens). Si vous considérez que les deux mots de la paire sont très similaires sémantiquement, vous pouvez choisir le point 7 (« tout à fait similaires »). Si vous considérez que les deux mots de la paire sont très différents sémantiquement, vous pouvez choisir le point 1 (« pas du tout similaires »). Vous pouvez utiliser tous les points de l’échelle. Par exemple, si la paire présentée est professeur – enseignant, vous pouvez choisir le point 6. Si la paire présentée est lune – route, vous pouvez choisir le point 1. N’hésitez pas à utiliser toute la gamme des chiffres comprise entre 1 et 7 mais ne vous préoccupez pas du nombre de fois que vous avez utilisé un chiffre en particulier tant qu’il fait référence à votre véritable jugement. Il n'y a pas de bonne ou de mauvaise réponse. Veuillez donc répondre le plus spontanément possible. Ne donnez pas d'éxplications. Les mots sont: 'négligence-faute'", 'Antwort': '5', 'Zeit': 2.3452064990997314}, 3: {'Prompt': "Nous allons vous présenter deux mots separées de un -. Votre tâche consiste à réfléchir au sens de ces mots et indiquer sur une échelle en 7 points à quel point vous considérez que ces deux mots sont similaires sémantiquement (qu’ils ont le même sens). Si vous considérez que les deux mots de la paire sont très similaires sémantiquemen ...
# Mean reaction time per participant: 272.66730739672977

# %% [markdown]
# In the **fifth block** we save the results from all test subjects in an Excel and csv file. These files subsequently store the answers of all LLMs-participants.

# %%
import pandas as pd
from datetime import datetime
import ast


# Dictionary to DataFrame conversion
def dict_to_dataframe(antworten_dict):
    rows = []
    for iteration, prompts in antworten_dict.items():
        for index, entry in prompts.items():
            for val in stimuli_dict.values():
                prompt_text = entry['Prompt']
                #print(val['wordPairs'])
                #print(prompt_text)#.split("'non':")[1].split("Si")[0].strip().replace("'", ""))
                if val['wordPairs'].strip() == prompt_text.split("Les mots sont:")[1].strip().replace("'", ""):
                  #print("yes")
                  rows.append({
                        "wordPairs": val['wordPairs'],
                        "PairMeanConcreteness": val['PairMeanConcreteness'],
                        "clusters": val['clusters'],
                        "MeanPairSimilarity": val['MeanPairSimilarity'],
                        "Informant": iteration,
                        "Index": index,
                        "Prompt": entry["Prompt"],
                        "models_answer": entry["Antwort"],
                        "time": 0,
                        "date": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    })
                else:
                  continue
                  #print("no",val['target_sent'].replace("'","").strip(),prompt_text.split("'non':")[1].split("Si")[0].strip().replace("'", ""))
    return pd.DataFrame(rows)

# Convert the dictionary to a DataFrame
new_data_df = dict_to_dataframe(antworten_null_shot_all)

# Save the DataFrame as new files
#new_data_df.to_excel('list1_Lakhzoum_gpt-40-mini_fewshot.xlsx', index=False)
new_data_df.to_csv('list1_Lakhzoum_o4-mini_fewshot.csv', index=False)

print("Data successfully saved!")
# Out:
# Data successfully saved!
